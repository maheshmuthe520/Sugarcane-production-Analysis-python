# %% [markdown]
# <a href="https://colab.research.google.com/github/maheshmuthe520/Sugarcane-production-Analysis-python/blob/main/Sugarcane_Production_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('List of Countries by Sugarcane Production.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %%
df.dtypes
# Out:
# Unnamed: 0                     int64
# Country                       object
# Continent                     object
# Production (Tons)             object
# Production per Person (Kg)    object
# Acreage (Hectare)             object
# Yield (Kg / Hectare)          object
# dtype: object

# %%
df.shape
# Out:
# (103, 7)

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace('.','', regex=False).astype(float)

# %%
df.rename(columns={'Production (Tons)':'Production_Tons','Production per Person (Kg)':'Production_per_Person _Kg','Acreage (Hectare)':'Acreage_Hectare','Yield (Kg / Hectare)':'Yield_Kg / Hectare'},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent  Production_Tons  \
# 0           0    Brazil  South America      768678382.0
# 1           1     India           Asia      348448000.0
# 2           2     China           Asia      123059739.0
# 3           3  Thailand           Asia       87468496.0
# 4           4  Pakistan           Asia       65450704.0
#
#   Production_per_Person _Kg Acreage_Hectare Yield_Kg / Hectare
# 0                 3.668,531      10.226.205           75.167,5
# 1                    260721       4.950.000           70.393,5
# 2                     88287       1.675.215           73.459,1
# 3                 1.264,303       1.336.575           65.442,2
# 4                    324219       1.130.820             57.879

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production_Tons              0
# Production_per_Person _Kg    0
# Acreage_Hectare              1
# Yield_Kg / Hectare           1
# dtype: int64

# %%
df[df['Acreage_Hectare'].isnull()]
# Out:
#     Unnamed: 0   Country Continent  Production_Tons Production_per_Person _Kg  \
# 99          99  Djibouti    Africa             53.0                        51
#
#    Acreage_Hectare Yield_Kg / Hectare
# 99             NaN                NaN

# %%
df=df.dropna().reset_index(drop=True)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df['Continent'].value_counts().plot(kind='bar')
plt.xlabel('Continent')
plt.ylabel('Number of Countries')
# Out:
# Text(0, 0.5, 'Number of Countries')

# %%
df.describe()
# Out:
#        Production_Tons
# count     1.020000e+02
# mean      1.850372e+07
# std       8.419149e+07
# min       1.000000e+00
# 25%       6.251875e+04
# 50%       1.440044e+06
# 75%       6.426824e+06
# max       7.686784e+08

# %%
plt.figure(figsize=(16,10))
plt.subplot(2,2,1)
sns.boxplot(df['Production_Tons'])
plt.title('Production_Tons')
plt.subplot(2,2,2)
sns.boxplot(df['Production_per_Person _Kg'])
plt.title('Production_per_Person ')
plt.subplot(2,2,3)
sns.boxplot(df['Acreage_Hectare'])
plt.title('Acreage_Hectare')
plt.subplot(2,2,4)
sns.boxplot(df['Yield_Kg / Hectare'])
plt.title('Yield_Kg / Hectare')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,2,1)
sns.histplot(df['Production_Tons'])
plt.title('Production_Tons')
plt.subplot(2,2,2)
sns.histplot(df['Production_per_Person _Kg'])
plt.title('Production_per_Person ')
plt.subplot(2,2,3)
sns.histplot(df['Acreage_Hectare'])
plt.title('Acreage_Hectare')
plt.subplot(2,2,4)
sns.histplot(df['Yield_Kg / Hectare'])
plt.title('Yield_Kg / Hectare')
# Out:
# Text(0.5, 1.0, 'Yield_Kg / Hectare')

# %%
sns.violinplot(df['Production_Tons'])
# Out:
# <Axes: ylabel='Production_Tons'>

# %%
df_africa=df[df['Continent']=='Africa']
df_africa.sort_values('Production_Tons',ascending=False)
# Out:
#                      Country Continent  Production_Tons  \
# 15                     Egypt    Africa       15760418.0
# 16              South Africa    Africa       15074610.0
# 22                     Kenya    Africa        7094619.0
# 26                 Swaziland    Africa        5583295.0
# 27                     Sudan    Africa        5525059.0
# 31                    Zambia    Africa        4285839.0
# 34                 Mauritius    Africa        3798448.0
# 35                    Uganda    Africa        3723019.0
# 36                  Zimbabwe    Africa        3483000.0
# 38                Madagascar    Africa        3005641.0
# 39                  Tanzania    Africa        2994127.0
# 40                    Malawi    Africa        2915406.0
# 41                Mozambique    Africa        2761505.0
# 44            Congo-Kinshasa    Africa        2191333.0
# 46             Côte d'Ivoire    Africa        1982661.0
# 52                  Ethiopia    Africa        1410312.0
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                  Production_Tons
# Production_Tons              1.0

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
plt.scatter(df['Acreage_Hectare'],df['Production_Tons'])
plt.xlabel('Acreage_Hectare')
plt.ylabel('Production_Tons')
# Out:
# Text(0, 0.5, 'Production_Tons')

# %%
df_Continent=df.groupby('Continent').count()

# %%
plt.scatter(df['Yield_Kg / Hectare'],df['Production_Tons'])
plt.xlabel('Yield_Kg / Hectare')
plt.ylabel('Production_Tons')
# Out:
# Text(0, 0.5, 'Production_Tons')

# %%
df_Continent.head()
# Out:
#                Country  Production_Tons  Production_per_Person _Kg  \
# Continent
# Africa              38               38                         38
# Asia                25               25                         25
# Europe               2                2                          2
# North America       22               22                         22
# Oceania              4                4                          4
#
#                Acreage_Hectare  Yield_Kg / Hectare
# Continent
# Africa                      38                  38
# Asia                        25                  25
# Europe                       2                   2
# North America               22                  22
# Oceania                      4                   4

# %%
df_Continent['Country'].sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Continent')
plt.ylabel('Number of Countries')
plt.title('Number of Countries per Continent')
# Out:
# Text(0.5, 1.0, 'Number of Countries per Continent')

# %%
df_Continent['Acreage_Hectare'].sort_values(ascending=False).plot(kind='bar')
plt.xlabel('Continent')
plt.ylabel('Acreage (Hectare)')
plt.title('Acreage (Hectare) by Continent')
# Out:
# Text(0.5, 1.0, 'Acreage (Hectare) by Continent')

# %%
df_Continent.corr(numeric_only=True)
# Out:
#                            Country  Production_Tons  \
# Country                        1.0              1.0
# Production_Tons                1.0              1.0
# Production_per_Person _Kg      1.0              1.0
# Acreage_Hectare                1.0              1.0
# Yield_Kg / Hectare             1.0              1.0
#
#                            Production_per_Person _Kg  Acreage_Hectare  \
# Country                                          1.0              1.0
# Production_Tons                                  1.0              1.0
# Production_per_Person _Kg                        1.0              1.0
# Acreage_Hectare                                  1.0              1.0
# Yield_Kg / Hectare                               1.0              1.0
#
#                            Yield_Kg / Hectare
# Country                                   1.0
# Production_Tons                           1.0
# Production_per_Person _Kg                 1.0
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_Continent.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %%
df.groupby('Continent')['Production_Tons'].sum().plot(kind='pie', autopct='%1.1f%%', figsize=(8, 8))
plt.title('Total Sugarcane Production by Continent')
plt.ylabel('')
# Out:
# Text(0, 0.5, '')
